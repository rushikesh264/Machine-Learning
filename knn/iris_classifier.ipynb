# %%
#importing liabraries
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
#loading dataset

data=pd.read_csv("dataset_iris.csv")
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#defining distance function
def euclid(d1,d2):
    dist=0
    for i in range(len(d2[0])):
        dist+=math.pow((d1[i]-d2[0][i]),2)
    return math.sqrt(dist)

# %%
#class prediction functin
def Predict(a):
    x=list(a.tolist())
    y=list(set(x))
    max=0
    prediction=""
    for i in y:
        c=x.count(i)
        if max<c:
            max=c
            prediction=i
    return prediction

# %%
#defining KNN function

def KNN(testdata,data,K=7):
    dist=[]
    
    #calculating distance of testdata from each instance
    for i in range(data.shape[0]):
        dist.append([round(euclid(testdata,data.iloc[i:i+1,1:5].values),2),data.iloc[i:i+1,-1:].values[0][0]])
    #sorting dist list
    dist.sort()
    dist=np.array(dist)
    
    #choosing K-Neareset Neighbours
    if K not in [2,3,5,7]:
        print("----------------------------------------------------------")
        print("KNN with K=",K)
        print("Nearest {0} neighbours:{1}".format(K,dist[:K,1].tolist()))
        print("Predicted class is :",Predict(dist[:K,1]))
        print("----------------------------------------------------------")
    else:
        print("----------------------------------------------------------") 
        print("KNN with K=2")
        print("Nearest 2 neighbours are:",dist[:2,1].tolist())
        print("Predicted class is :",Predict(dist[:K,1]))
        print("----------------------------------------------------------")

        print("KNN with K=3")
        print("Nearest 3 neighbours are:",dist[:3,1].tolist())
        print("Predicted class is :",Predict(dist[:K,1]))
        print("----------------------------------------------------------")

        print("KNN with K=5")
        print("Nearest 5 neighbours are:",dist[:5,1].tolist())
        print("Predicted class is :",Predict(dist[:K,1]))
        print("----------------------------------------------------------")
        
        print("KNN with K=7")
        print("Nearest 7 neighbours are:",dist[:7,1].tolist())
        print("Predicted class is :",Predict(dist[:K,1]))
        print("----------------------------------------------------------")
    
    
    
    
test_instance=np.array([5.7,2.0,4.2,1.0])
K=int(input("Enter value of K:"))
KNN(test_instance,data,K)
# Out:
# Enter value of K:5
# ----------------------------------------------------------
# KNN with K=2
# Nearest 2 neighbours are: ['Iris-versicolor', 'Iris-versicolor']
# Predicted class is : Iris-versicolor
# ----------------------------------------------------------
# KNN with K=3
# Nearest 3 neighbours are: ['Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor']
# Predicted class is : Iris-versicolor
# ----------------------------------------------------------
# KNN with K=5
# Nearest 5 neighbours are: ['Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor']
# Predicted class is : Iris-versicolor
# ----------------------------------------------------------
# KNN with K=7
# Nearest 7 neighbours are: ['Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor']
# Predicted class is : Iris-versicolor
# ----------------------------------------------------------
