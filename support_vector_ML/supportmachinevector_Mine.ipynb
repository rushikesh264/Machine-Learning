# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from matplotlib.animation import FuncAnimation
'''data, label = make_classification(
    n_features=2,
    n_classes=2,
    n_samples=200,
    n_redundant=0,
    n_clusters_per_class=1
)
'''
from sklearn.datasets.samples_generator import make_blobs
#we will select 40 points with 2 centers(groups) and each group has 20 points
#data,label=make_blobs(n_samples=40,centers=2,random_state=20)
#l=[]
'''for x in label:
    if x==0:
        l.append(-1)
    else:
        l.append(1)
label=l'''
data,label =make_blobs(n_samples=50, n_features=2, centers=2, cluster_std=1.05, random_state=40)
label = np.where(label <= 0, -1, 1)
#data=np.array([[1, 3], [4, 4], [2, 4], [5, 5], [3, 2]])
#label=np.array([0, 1, 0, 0, 1])
w=[0,0,0]
b=0
lii=[]
#df.plot.scatter(x="year",y="length",c=colors)
color=label
for i in range(1000):
    for j in range(len(data)):
        m=((w[1]*data[j][0])+(w[2]*data[j][1])-b)  
        if (m*label[j])>=1:
            w[1]-=0.001*(2*0.01*w[1])
            w[2]-=0.001*(2*0.01*w[2])
        else:
            w[1]-=0.001*(2*0.01*w[1]-(data[j][0]*label[j]))
            w[2]-=0.001*(2*0.01*w[2]-(data[j][1]*label[j]))
            b-=0.001*label[j]
def get_hyperplane_value(x, w, b, offset):
          return (-w[1] * x + b + offset) / w[2]
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(data[:,0],data[:,1],c=color)
x0_1 = np.amin(data[:,0])
x0_2 = np.amax(data[:,0])

x1_1 = get_hyperplane_value(x0_1, w, b, 0)
x1_2 = get_hyperplane_value(x0_2, w, b, 0)

x1_1_m = get_hyperplane_value(x0_1, w, b, -1)
x1_2_m = get_hyperplane_value(x0_2, w, b, -1)

x1_1_p = get_hyperplane_value(x0_1, w, b, 1)
x1_2_p = get_hyperplane_value(x0_2, w, b, 1)

ax.plot([x0_1, x0_2],[x1_1, x1_2], 'y--')
ax.plot([x0_1, x0_2],[x1_1_m, x1_2_m], 'k')
ax.plot([x0_1, x0_2],[x1_1_p, x1_2_p], 'k')

x1_min = np.amin(data[:,1])
x1_max = np.amax(data[:,1])
ax.set_ylim([x1_min-3,x1_max+3])
'''                
X=np.array([1,5])
fig,ax=plt.subplots()
fig.set_tight_layout(True)
ax.scatter(data[:,0],data[:,1])
slope=lii[0][0]
intercept=lii[0][1]
line,=ax.plot(X,X*slope+intercept)

ani=FuncAnimation(fig,animate
                  ,frames=np.arange(0,50),interval=100)
ani.save("x.gif",dpi=100,writer='imagemagick')
def animate(i):
    slope=lii[i][0]
    intercept=lii[i][1]
    line.set_data(X,X*slope+intercept)
    return line,ax
'''
# Out:
# C:\Users\Roshan\.conda\envs\HEllo\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)
# '                \nX=np.array([1,5])\nfig,ax=plt.subplots()\nfig.set_tight_layout(True)\nax.scatter(data[:,0],data[:,1])\nslope=lii[0][0]\nintercept=lii[0][1]\nline,=ax.plot(X,X*slope+intercept)\n\nani=FuncAnimation(fig,animate\n                  ,frames=np.arange(0,50),interval=100)\nani.save("x.gif",dpi=100,writer=\'imagemagick\')\ndef animate(i):\n    slope=lii[i][0]\n    intercept=lii[i][1]\n    line.set_data(X,X*slope+intercept)\n    return line,ax\n'
